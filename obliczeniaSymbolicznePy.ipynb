# %%
import sympy as sp

# Zmienne
h1, h2, F1, Fd = sp.symbols('h1 h2 F1 Fd', positive=True)

# Funkcje
f1 = (F1 + Fd - 23*sp.sqrt(h1)) / (0.7*h1)
f2 = (23*sp.sqrt(h1) - 30*sp.sqrt(h2)) / (1.35*h2**2)

# %%
df1_h1 = sp.diff(f1, h1)
df1_h1
# Out:
# -1.42857142857143*(F1 + Fd - 23*sqrt(h1))/h1**2 - 16.4285714285714/h1**(3/2)

# %%
df1_h2 = sp.diff(f1, h2)
df1_h2
# Out:
# 0

# %%
df1_F1 = sp.diff(f1, F1)
df1_F1
# Out:
# 1.42857142857143/h1

# %%
df1_Fd = sp.diff(f1, Fd)
df1_Fd
# Out:
# 1.42857142857143/h1

# %%
df2_h1 = sp.diff(f2, h1)
df2_h1
# Out:
# 8.51851851851852/(sqrt(h1)*h2**2)

# %%
df2_h2 = sp.diff(f2, h2)
df2_h2
# Out:
# -1.48148148148148*(23*sqrt(h1) - 30*sqrt(h2))/h2**3 - 11.1111111111111/h2**(5/2)

# %%
df2_F1 = sp.diff(f2, F1)
df2_F1
# Out:
# 0

# %%
df2_Fd = sp.diff(f2, Fd)
df2_Fd
# Out:
# 0
